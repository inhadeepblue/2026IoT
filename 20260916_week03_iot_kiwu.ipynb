# %%
import pandas as pd

subject_dict = {
    '국':[99, 100, 89, 93],
    '영':[97, 91, 88, 92],
    '수':[100, 86, 94, 99]}
# print(subject_dict)
df1 = pd.DataFrame(subject_dict)#, index=[1, 2, 3, 4])
print(df1)
# Out:
#      국   영    수
# 0   99  97  100
# 1  100  91   86
# 2   89  88   94
# 3   93  92   99

# %%
import seaborn as sns

df2 = sns.load_dataset('mpg')  # 미국 자동차 연비 데이터셋 (1970~80년대 자료)
# print(df2.info())
# print(df2.tail(3))
# print(df2['mpg'])
# df2 = df2.sort_values('mpg')  # 전체 데이터셋을 연비 순으로 정렬 (오름차순)
# df2 = df2.sort_values('mpg', ascending=False)  # 전체 데이터셋을 연비 순으로 정렬 (내림차순)
# print(df2)
print(df2.isnull().sum())
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
# print(df2['horsepower'].isna())  # isna() 결측값이면 True 반환, 아니면 False 반환
print(df2[df2['horsepower'].isna()])  # 데이터프레임에서 마력이 누락된 행 추출

# df2 = df2.drop(columns='horsepower')  # 결측치가 있는 마력 열 삭제
# df2 = df2.drop(columns=['horsepower','cylinders'])  # 결측치가 있는 마력 열 삭제

# df2 = df2.dropna()  # 결측치가 존재하는 행 삭제 (이 데이터셋에서는 마력이 누락된 6개 행 삭제)
# df2.dropna(subset='horsepower', inplace=True)  # 위 행과 동일하게 원본을 overwrite
# print(df2.info())
# print(df2.iloc[30:35])  # 30행부터 34번행까지 출력

# df2 = df2.fillna(99)
# df2 = df2.fillna(df2['horsepower'].mean())  # 결측값을 마력 산술평균 값으로 채워넣음. 중앙값도 사용 가능 median()
# print(df2.iloc[30:35])  # 30행부터 34번행까지 출력

# print(df2.describe())  # 요약통계량
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32   25.0          4          98.0         NaN    2046          19.0
# 126  21.0          6         200.0         NaN    2875          17.0
# 330  40.9          4          85.0         NaN    1835          17.3
# 336  23.6          4         140.0         NaN    2905          14.3
# 354  34.5          4         100.0         NaN    2320          15.8
# 374  23.0          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
# cylinders 그룹별 horsepower의 중앙값으로 결측치 채우기
df2['horsepower'] = df2['horsepower'].fillna(
    df2.groupby('cylinders')['horsepower'].transform('median')
)

# 결측치가 잘 채워졌는지 확인 (0이 나와야 합니다)
# print(df2['horsepower'].isnull().sum())

print(df2.iloc[32:33])  # 4기통 차량 확인
print(df2.iloc[126:127])  # 6기통 차량 확인
# print(df2.at[126, 'horsepower'])  # 6기통 차량 마력 확인
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32  25.0          4          98.0        78.0    2046          19.0
#
#     model_year origin        name
# 32          71    usa  ford pinto
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 126  21.0          6         200.0       100.0    2875          17.0
#
#      model_year origin           name
# 126          74    usa  ford maverick
